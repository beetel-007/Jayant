# %% [markdown]
# # UNI-variable Plots
# - histograms
# - Density Plots
# - Box Plots
# - Line chart
# # BI-variant Plots
# - Heat Map
# - Scatter Plot
# - Pie Plot

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #graph matlab , module-pyplot
import seaborn as sns #to make graph creative
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
os.chdir('C:\\Users\\Asus\\Desktop\\Data Visulization')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Asus\\Desktop\\Data Visulization'

# %%
data=pd.read_csv("hrdata.csv")
data2=pd.read_csv("MMix.csv")
data3=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %% [markdown]
# # Histogram

# %%
plt.hist(data.Income)
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data.Income,bins=20) #hist-histogram
# Out:
# (array([ 33., 332., 154., 195., 171., 119.,  69.,  40.,  42.,  68.,  38.,
#          18.,  21.,  31.,   7.,  11.,  30.,  24.,  21.,  46.]),
#  array([ 1009. ,  1958.5,  2908. ,  3857.5,  4807. ,  5756.5,  6706. ,
#          7655.5,  8605. ,  9554.5, 10504. , 11453.5, 12403. , 13352.5,
#         14302. , 15251.5, 16201. , 17150.5, 18100. , 19049.5, 19999. ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data.Income,bins=20,color='green') #bins-to use more prescribe graph
# Out:
# (array([ 33., 332., 154., 195., 171., 119.,  69.,  40.,  42.,  68.,  38.,
#          18.,  21.,  31.,   7.,  11.,  30.,  24.,  21.,  46.]),
#  array([ 1009. ,  1958.5,  2908. ,  3857.5,  4807. ,  5756.5,  6706. ,
#          7655.5,  8605. ,  9554.5, 10504. , 11453.5, 12403. , 13352.5,
#         14302. , 15251.5, 16201. , 17150.5, 18100. , 19049.5, 19999. ]),
#  <a list of 20 Patch objects>)

# %%
plt.figure(figsize=(15,7)) #to set size of the graph
plt.hist(data.Income,bins=20,color='Black',alpha=0.8) #alpha-to provide trasnparency to graph
plt.xlabel("income")
plt.ylabel("frequency(no of employees)")
plt.title("Histogram.income")
plt.show()

# %%
from matplotlib import style #to add effect or details in the graph

# %%
style.use("classic")
plt.figure(figsize=(15,7)) #to set size of the graph
plt.hist(data.Income,bins=20,color='green',alpha=0.8) #alpha-to provide trasnparency to graph
plt.xlabel("income")
plt.ylabel("frequency(no of employees)")
plt.title("Histogram.income")
plt.tight_layout()
#plt.savefig("histogram.pdf")

# %% [markdown]
# # Density plot

# %%
data['Income'].plot(kind='density', ls="--") #ls-line style

# %%
data['Income'].plot(kind='density')
plt.xlabel("income")
plt.ylabel("frequency")
plt.title("density")
plt.tight_layout
plt.figure(figsize=(15,7))

# %% [markdown]
# # Histogram with density plot

# %%
ax=data['Income'].plot(kind='hist',color='lightblue')
ax2=data['Income'].plot(kind='density', secondary_y=True,color='blue')
ax.set_ylabel("frequency(no of employees)")
ax2.set_ylabel("Density")
ax.set_xlabel("Income")
# Out:
# Text(0.5, 0, 'Income')

# %% [markdown]
# # Boxplot

# %%
plt.boxplot(data['Income']) #boxplot only for numeric values
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1af6ee2f128>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1af6ee36898>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1af6ee2fac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1af700afba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1af6eda1668>],
#  'means': []}

# %%
plt.boxplot(data['Income'], vert=False) #to plot on vertical axis
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1af6fa7ea58>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1af6fa7e588>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1af6fa7ef60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1af6f702550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1af6f7023c8>],
#  'means': []}

# %%
data3.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.boxplot(data=data3,orient='h',palette='Set3') #orientation and palette

# %% [markdown]
# # line chart

# %%
plt.plot(data2['NewVolSales'])

# %% [markdown]
# # scatter plot

# %%
plt.scatter(x=data['Age'],y=data['Income'])

# %% [markdown]
# # Heat Map

# %%
#to plot corelation

# %%
sns.heatmap(data3.corr())

# %%
sns.heatmap(data3.corr(),annot=True) #to show values on the plot
